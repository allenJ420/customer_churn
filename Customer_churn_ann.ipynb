# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop(['customerID'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female              0     Yes  ...          29.85         29.85    No
# 1    Male              0      No  ...          56.95        1889.5    No
# 2    Male              0      No  ...          53.85        108.15   Yes
# 3    Male              0      No  ...          42.30       1840.75    No
# 4  Female              0      No  ...          70.70        151.65   Yes
#
# [5 rows x 20 columns]

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df[pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 488   Female              0     Yes  ...          52.55                  No
# 753     Male              0      No  ...          20.25                  No
# 936   Female              0     Yes  ...          80.85                  No
# 1082    Male              0     Yes  ...          25.75                  No
# 1340  Female              0     Yes  ...          56.05                  No
# 3331    Male              0     Yes  ...          19.85                  No
# 3826    Male              0     Yes  ...          25.35                  No
# 4380  Female              0     Yes  ...          20.00                  No
# 5218    Male              0     Yes  ...          19.70                  No
# 6670  Female              0     Yes  ...          73.35                  No
# 6754    Male              0      No  ...          61.90                  No
#
# [11 rows x 20 columns]

# %%
df1 = df[df['TotalCharges'] != ' ']

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
tenure_churn_no = df1[df1['Churn']== 'No'].tenure

tenure_churn_yes = df1[df1['Churn']== 'Yes'].tenure

plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['Churn = Yes', 'Churn= No'])
plt.xlabel('Tenure')
plt.ylabel('No of Customers')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
import seaborn as sns

# %%
tenure_churn_no = df1[df1['Churn']== 'No'].MonthlyCharges

tenure_churn_yes = df1[df1['Churn']== 'Yes'].MonthlyCharges

plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['Churn = Yes', 'Churn= No'])
plt.xlabel('MonthlyCharges')
plt.ylabel('No of Customers')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df1.head(3)
# Out:
#    gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female              0     Yes  ...          29.85         29.85    No
# 1    Male              0      No  ...          56.95       1889.50    No
# 2    Male              0      No  ...          53.85        108.15   Yes
#
# [3 rows x 20 columns]

# %%
import numpy as np

# %%
df1_categ = df1.select_dtypes(include=[np.object])
df1_categ_col  = df1_categ.columns
df1_categ_col

def print_uniq_values(df1_categ_col):
  for categ in df1_categ_col:
    uniq = df1[categ].unique()
    print(f'{categ} : {uniq}')

# %%
# Replacing the categorical values

df1.replace('No phone service','No', inplace=True)
df1.replace('No internet service','No', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
print_uniq_values(df1)
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges : [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges : [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn : ['No' 'Yes']

# %%
##Convert Yes and No to 1 or 0

yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
##One hot encoding for categorical columns

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 2592       1  ...                           1
# 5319       1  ...                           1
# 5361       1  ...                           1
# 5576       1  ...                           1
# 2934       1  ...                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 0          1  ...                           0
# 1          0  ...                           1
# 2          0  ...                           1
# 3          0  ...                           0
# 4          1  ...                           0
# ...      ...  ...                         ...
# 7038       0  ...                           1
# 7039       1  ...                           0
# 7040       1  ...                           0
# 7041       0  ...                           1
# 7042       0  ...                           0
#
# [7032 rows x 27 columns]

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
##Train test split

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
len(X_train.columns)
# Out:
# 26

# %% [markdown]
# **Build a model (ANN) in tensorflow/keras**

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ***Using Hyper Parameter Tuning***

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
# !pip install -q -U keras-tuner

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='my_dir',
    project_name='Customer Churn')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/Customer Churn/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/Customer Churn/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 15
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
y_test.shape
# Out:
# (1407,)

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir/Customer Churn
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 256
# units_1: 512
# learning_rate: 0.0001
# units_2: 384
# units_3: 320
# units_4: 288
# units_5: 192
# units_6: 320
# units_7: 64
# units_8: 352
# units_9: 352
# units_10: 480
# Score: 0.8052594264348348
# Trial summary
# Hyperparameters:
# num_layers: 11
# units_0: 352
# units_1: 448
# learning_rate: 0.0001
# units_2: 384
# units_3: 128
# units_4: 96
# units_5: 224
# units_6: 192
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# Score: 0.8014688690503439
# Trial summary
# Hyperparameters:
# num_layers: 7
# units_0: 256
# units_1: 288
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# Score: 0.800521194934845
# Trial summary
# Hyperparameters:
# num_layers: 13
# units_0: 192
# units_1: 384
# learning_rate: 0.01
# units_2: 448
# units_3: 192
# units_4: 384
# units_5: 256
# units_6: 128
# units_7: 256
# units_8: 96
# units_9: 128
# units_10: 128
# units_11: 32
# units_12: 32
# Score: 0.7941246231396993
# Trial summary
# Hyperparameters:
# num_layers: 13
# units_0: 64
# units_1: 160
# learning_rate: 0.01
# units_2: 384
# units_3: 96
# units_4: 448
# units_5: 288
# units_6: 128
# units_7: 224
# units_8: 192
# units_9: 448
# units_10: 448
# units_11: 128
# units_12: 352
# Score: 0.7654584248860677

# %%
model1 = keras.Sequential([
                          keras.layers.Dense(26, input_shape = (26,), activation = 'relu'),
                          keras.layers.Dense(256, activation='relu'),
                          keras.layers.Dense(512, activation='relu'),
                          keras.layers.Dense(384, activation='relu'),
                          keras.layers.Dense(320, activation='relu'),
                          keras.layers.Dense(288, activation='relu'),
                          keras.layers.Dense(1, activation='sigmoid')
])

#model.summary()

#opt = keras.optimizers.Adam(learning_rate=0.01)

model1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model1.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4842 - accuracy: 0.7447
# Epoch 2/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4321 - accuracy: 0.7995
# Epoch 3/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4244 - accuracy: 0.7956
# Epoch 4/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4097 - accuracy: 0.8054
# Epoch 5/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4006 - accuracy: 0.8112
# Epoch 6/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4086 - accuracy: 0.8013
# Epoch 7/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3929 - accuracy: 0.8138
# Epoch 8/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3915 - accuracy: 0.8189
# Epoch 9/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3930 - accuracy: 0.8150
# Epoch 10/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3680 - accuracy: 0.8296
# Epoch 11/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3789 - accuracy: 0.8178
# Epoch 12/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3649 - accuracy: 0.8332
# Epoch 13/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3640 - accuracy: 0.8253
# Epoch 14/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3679 - accuracy: 0.8382
# Epoch 15/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3604 - accuracy: 0.8260
# Epoch 16/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3351 - accuracy: 0.8448
# Epoch 17/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3227 - accuracy: 0.8577
# Epoch 18/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3055 - accuracy: 0.8504
# Epoch 19/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3074 - accuracy: 0.8587
# Epoch 20/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2942 - accuracy: 0.8603
# Epoch 21/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2636 - accuracy: 0.8741
# Epoch 22/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2538 - accuracy: 0.8787
# Epoch 23/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2457 - accuracy: 0.8852
# Epoch 24/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2382 - accuracy: 0.8874
# Epoch 25/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2292 - accuracy: 0.8927
# Epoch 26/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2097 - accuracy: 0.8976
# Epoch 27/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2030 - accuracy: 0.8970
# Epoch 28/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1900 - accuracy: 0.9130
# Epoch 29/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1985 - accuracy: 0.9017
# Epoch 30/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1745 - accuracy: 0.9177
# Epoch 31/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1571 - accuracy: 0.9232
# Epoch 32/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1674 - accuracy: 0.9220
# Epoch 33/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1632 - accuracy: 0.9231
# Epoch 34/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1704 - accuracy: 0.9223
# Epoch 35/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1546 - accuracy: 0.9296
# Epoch 36/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1525 - accuracy: 0.9223
# Epoch 37/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1461 - accuracy: 0.9284
# Epoch 38/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1467 - accuracy: 0.9312
# Epoch 39/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1469 - accuracy: 0.9332
# Epoch 40/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1478 - accuracy: 0.9283
# Epoch 41/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1312 - accuracy: 0.9371
# Epoch 42/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1426 - accuracy: 0.9397
# Epoch 43/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1322 - accuracy: 0.9381
# Epoch 44/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1346 - accuracy: 0.9362
# Epoch 45/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1201 - accuracy: 0.9425
# Epoch 46/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1293 - accuracy: 0.9429
# Epoch 47/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1283 - accuracy: 0.9387
# Epoch 48/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1146 - accuracy: 0.9440
# Epoch 49/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1428 - accuracy: 0.9375
# Epoch 50/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1335 - accuracy: 0.9339
# Epoch 51/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1310 - accuracy: 0.9352
# Epoch 52/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1291 - accuracy: 0.9388
# Epoch 53/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1370 - accuracy: 0.9414
# Epoch 54/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1143 - accuracy: 0.9439
# Epoch 55/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1211 - accuracy: 0.9434
# Epoch 56/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1246 - accuracy: 0.9389
# Epoch 57/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1128 - accuracy: 0.9454
# Epoch 58/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1096 - accuracy: 0.9420
# Epoch 59/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1275 - accuracy: 0.9407
# Epoch 60/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1078 - accuracy: 0.9452
# Epoch 61/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1060 - accuracy: 0.9470
# Epoch 62/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1304 - accuracy: 0.9381
# Epoch 63/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9502
# Epoch 64/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1083 - accuracy: 0.9484
# Epoch 65/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1216 - accuracy: 0.9447
# Epoch 66/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1054 - accuracy: 0.9474
# Epoch 67/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1009 - accuracy: 0.9485
# Epoch 68/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.9459
# Epoch 69/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1038 - accuracy: 0.9526
# Epoch 70/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1083 - accuracy: 0.9435
# Epoch 71/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1122 - accuracy: 0.9483
# Epoch 72/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1062 - accuracy: 0.9467
# Epoch 73/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1217 - accuracy: 0.9422
# Epoch 74/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0993 - accuracy: 0.9463
# Epoch 75/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1028 - accuracy: 0.9490
# Epoch 76/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1190 - accuracy: 0.9423
# Epoch 77/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1022 - accuracy: 0.9544
# Epoch 78/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1026 - accuracy: 0.9481
# Epoch 79/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1055 - accuracy: 0.9477
# Epoch 80/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0895 - accuracy: 0.9556
# Epoch 81/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0905 - accuracy: 0.9551
# Epoch 82/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1281 - accuracy: 0.9419
# Epoch 83/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1095 - accuracy: 0.9437
# Epoch 84/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0985 - accuracy: 0.9472
# Epoch 85/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1118 - accuracy: 0.9448
# Epoch 86/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0931 - accuracy: 0.9532
# Epoch 87/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1010 - accuracy: 0.9490
# Epoch 88/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1125 - accuracy: 0.9444
# Epoch 89/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1102 - accuracy: 0.9406
# Epoch 90/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1115 - accuracy: 0.9468
# Epoch 91/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1065 - accuracy: 0.9430
# Epoch 92/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1078 - accuracy: 0.9449
# Epoch 93/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1102 - accuracy: 0.9447
# Epoch 94/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1115 - accuracy: 0.9441
# Epoch 95/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9487
# Epoch 96/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1082 - accuracy: 0.9462
# Epoch 97/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1230 - accuracy: 0.9395
# Epoch 98/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9528
# Epoch 99/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0954 - accuracy: 0.9545
# Epoch 100/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.0864 - accuracy: 0.9555

# %%
model1.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 3ms/step - loss: 2.0974 - accuracy: 0.7619
# [2.0974392890930176, 0.761904776096344]

# %%
yp1 = model1.predict(X_test)
yp1[:5]
# Out:
# array([[2.87922204e-01],
#        [2.30188936e-12],
#        [1.18073426e-01],
#        [6.21591449e-01],
#        [9.99314308e-01]], dtype=float32)

# %%
y_pred1 = []
for element in yp1:
    if element > 0.5:
        y_pred1.append(1)
    else:
        y_pred1.append(0)

# %%
y_pred1[:10]
# Out:
# [0, 0, 0, 1, 1, 0, 0, 1, 0, 0]

# %%
y_test[:10]
# Out:
# 5561    0
# 5814    0
# 2645    0
# 3983    1
# 6438    1
# 4561    0
# 6271    0
# 4081    1
# 3937    0
# 1357    0
# Name: Churn, dtype: int64

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      1038
#            1       0.55      0.48      0.51       369
#
#     accuracy                           0.76      1407
#    macro avg       0.69      0.67      0.68      1407
# weighted avg       0.75      0.76      0.76      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred1)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
